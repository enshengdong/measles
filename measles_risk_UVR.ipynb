# %% [markdown]
# # US_Measles_Risk_UVR
#
# ### Task 1. Raw measles risk
# Calculate raw risk for each county with $$ r_{ij}^{t} = C_{i}^{t} \times V_{ij}^{t} \times UVR_{j}^{t} \times P_{j}^{t} $$
# where <br/>
# $i$ is the origin country, <br/>
# $j$ is the US county, <br/>
# $t$ is the year, <br/>
# $r_{ij}^{t}$ is the measles risk from country $i$ to county $j$ in year $t$, <br/>
# $C_{i}^{t}$ is the case incidence in Country $i$ in year $t$, <br/>
# $V_{ij}^{t}$ is the travel volume (million) from country $i$ to county $j$ in year $t$, <br/>
# $UVR_{j}^{t}$ is 1 - vaccination rate in county $j$ in year $t$, <br/>
# $P_{j}^{t}$ is the county $j$ population in year $t$. <br/>
# $$ r_{j}^{t} = \sum_{i} r_{ij}^{t} = (\sum_{i} C_{i}^{t} \times V_{ij}^{t}) \times UVR_{j}^{t} \times P_{j}^{t}$$
# where <br/>
# $r_{j}^{t}$ is the measles risk of county $j$ in year $t$, <br/>
#
# ### Task 2. Rearrange travel volume by population
# For counties where is no international travel - update $V_{ij}^{t}$. <br/>
# Task 2.1: calculate the average of raw risk in neighboring counties <br/>
# Task 2.2: proportion to population <br/>
#
# ### Task 3. Rearrange travel volume by Voronoi diagram
#
# ####  Goal:
# Update $V_{ij}^{t}$ for all US counties.
# #### Preparation:
# Create Thiessen polygons for all known __675__ airports in the US (in `Voronoi.mxd`).
# 1. Make sure the airports layer contains IATA code and cooridates.
# * `Create Thiessen Polygons` for `US_airports_675` to create `US_airports_Thiessen` (Output Fields: ALL).
# * `Dissolve` `us_states` to create `US_Boundary` as the mask.
# * `Clip` `US_airports_Thiessen` with `US_Boundary` to make sure all Thiessen polygons are within the US. Output: `US_airports_Thiessen_Clip`.
# * Calculate geometry (`ThiessenAreaKM2`) for each Thiessen polygon.
# * `Intersect` `US_airports_Thiessen_Clip` and `us_states` to get `Thiessen_County_Intersect`.
# * Calcuate geometry (`IntersectAreaKM2`) for each polygon in `Thiessen_County_Intersect`.
# * Calcuate percentage of intersected polygon to the airport Thiessen polygon (`ThiessenAreaPct = [IntersectAreaKM2] * 100/ [ThiessenAreaKM2]`).
# * Export `Thiessen_County_Intersect` as `Thiessen_County_Intersect_Pct.csv`
#
# #### Method:
# Diffusing international incoming travel volume ( $V_{ij}^{t}$) to all neighboring counties.

# %% [markdown]
# ## Task 1: Calculate measles risk in county level

# %%
# environment setting
import pandas as pd
import datetime
t = datetime.datetime.now()
year = 2019 # only support 2019 in this script
year_pop = 'pop2019'
s_or_c = 'confirmed' # confirmed, suspected
year_iata = 2018 # we use 2018 IATA data for 2018 and 2019 (2007 to 2018)
out_folder = r'C:\Users\Ensheng\Desktop\mapping\Data_Output\\'
#pd.set_option("display.max_rows", 999)

# %% [markdown]
# #### Import US measles cases

# %%
in_table = r"C:\Users\Ensheng\Desktop\mapping\Data_Cases\Reported_Measles_US_Counties\reported_cases.csv"
real_case = pd.read_csv(in_table)
real_case = real_case[['FIPS','# of Cases','intl_case']]
print(len(real_case))
real_case.head(3)
# Out:
# 97
#    FIPS  # of Cases  intl_case
# 0  2122         1.0        NaN
# 1  4019         1.0        1.0
# 2  6001         1.0        NaN

# %% [markdown]
# #### Import world population

# %%
# ref: https://population.un.org/wpp/Download/Standard/Population/
in_table = r'C:\Users\Ensheng\Desktop\mapping\scripts\world_pop.xlsx'
df_pop = pd.read_excel(in_table)
print(len(df_pop))
df_pop.head(5)
# Out:
# 235
#              name  Country code   pop1950   pop1951   pop1952   pop1953  \
# 0     Afghanistan             4  7752.118  7840.156  7935.997  8039.694
# 1         Albania             8  1263.174  1287.500  1316.093  1348.112
# 2         Algeria            12  8872.247  9023.269  9186.138  9364.371
# 3  American Samoa            16    18.940    19.293    19.542    19.695
# 4         Andorra            20     6.196     6.689     7.247     7.865
#
#     pop1954   pop1955    pop1956    pop1957  ...    pop2011    pop2012  \
# 0  8151.317  8270.991   8398.875   8535.163  ...  30117.413  31161.376
# 1  1382.898  1419.994   1459.120   1500.181  ...   2928.592   2914.096
# 2  9560.149  9774.283  10006.147  10253.778  ...  36661.445  37383.895
# 3    19.753    19.754     19.709     19.667  ...     55.759     55.667
# 4     8.525     9.232      9.989     10.779  ...     83.747     82.427
#
#      pop2013    pop2014    pop2015    pop2016    pop2017    pop2018  \
# 0  32269.589  33370.794  34413.603  35383.032  36296.113  37171.921
# 1   2903.790   2896.305   2890.513   2886.438   2884.169   2882.740
# 2  38140.133  38923.692  39728.025  40551.392  41389.189  42228.408
# 3     55.713     55.791     55.812     55.741     55.620     55.465
# 4     80.774     79.213     78.011     77.297     77.001     77.006
#
#      pop2019    pop2020
# 0  38041.754  38928.346
# 1   2880.917   2877.797
# 2  43053.054  43851.044
# 3     55.312     55.191
# 4     77.142     77.265
#
# [5 rows x 73 columns]

# %%
# ref: http://worldpopulationreview.com/country-codes/
# ref: https://www.iban.com/country-codes
# note: add BLM manually
in_table = r'C:\Users\Ensheng\Desktop\mapping\diffusion_model\country_code.csv'
df_code = pd.read_csv(in_table)
print(len(df_code))
df_code.head(5)
# Out:
# 238
#              name alpha2 alpha3  num3
# 0     Afghanistan     AF    AFG     4
# 1         Albania     AL    ALB     8
# 2         Algeria     DZ    DZA    12
# 3  American Samoa     AS    ASM    16
# 4         Andorra     AD    AND    20

# %%
df_pop3 = pd.merge(df_pop, df_code, how='left', left_on='Country code',right_on='num3')
print("Info: " + str(len(df_pop3)) + " countries in UN dataset.")
print("Warning: " + str(len(df_pop3.loc[df_pop3['num3'].isnull()])) + " countries mismatched.")
df_pop3.head(3)
# Out:
# Info: 235 countries in UN dataset.
# Warning: 0 countries mismatched.
#         name_x  Country code   pop1950   pop1951   pop1952   pop1953  \
# 0  Afghanistan             4  7752.118  7840.156  7935.997  8039.694
# 1      Albania             8  1263.174  1287.500  1316.093  1348.112
# 2      Algeria            12  8872.247  9023.269  9186.138  9364.371
#
#     pop1954   pop1955    pop1956    pop1957  ...    pop2015    pop2016  \
# 0  8151.317  8270.991   8398.875   8535.163  ...  34413.603  35383.032
# 1  1382.898  1419.994   1459.120   1500.181  ...   2890.513   2886.438
# 2  9560.149  9774.283  10006.147  10253.778  ...  39728.025  40551.392
#
#      pop2017    pop2018    pop2019    pop2020       name_y  alpha2  alpha3  \
# 0  36296.113  37171.921  38041.754  38928.346  Afghanistan      AF     AFG
# 1   2884.169   2882.740   2880.917   2877.797      Albania      AL     ALB
# 2  41389.189  42228.408  43053.054  43851.044      Algeria      DZ     DZA
#
#    num3
# 0     4
# 1     8
# 2    12
#
# [3 rows x 77 columns]

# %% [markdown]
# #### Import WHO data

# %%
# if year != 2019:
print (year, s_or_c)
# ref: https://www.who.int/immunization/monitoring_surveillance/burden/vpd/surveillance_type/active/measles_monthlydata/en/
in_table = r'C:\Users\Ensheng\Desktop\mapping\Data_Cases\WHO_Measles\WHO_Measles_Dec2019.xlsx'
df_who = pd.read_excel(in_table, sheet_name=s_or_c)
print(len(df_who), "countries")
df_outbreak_raw = df_who
df_outbreak_raw.head(3)
# Out:
# 2019 confirmed
# 194 countries
#   ISO3      Country     Total
# 0  MDG   Madagascar  127575.0
# 1  UKR      Ukraine   56986.0
# 2  PHL  Philippines   42467.0

# %%
df_outbreak_raw[df_outbreak_raw['Country']=='Tonga']
# Out:
#     ISO3 Country  Total
# 105  TON   Tonga  440.0

# %%
# if year != 2019:
print (year)
# ref: https://www.who.int/immunization/monitoring_surveillance/burden/vpd/surveillance_type/active/measles_monthlydata/en/
# in_table = r'C:\Users\Ensheng\Desktop\mapping\diffusion_model\measlescasesbycountrybymonth.xls'
# df_who = pd.read_excel(in_table,sheet_name='WEB')
# df_who = df_who.loc[df_who['Year'] == year]

# col_list= list(df_who)
# col_list.remove('Year')
# df_who['Total'] = df_who[col_list].sum(axis=1)
# print(len(df_who))
# df_outbreak_raw = df_who[['ISO3','Country','Total']]
    
# df_outbreak_raw.head(3)
# Out:
# 2019

# %%
df_outbreak = pd.merge(df_outbreak_raw, df_pop3, how='left', left_on='ISO3',right_on='alpha3')
print(len(df_outbreak))
df_outbreak = df_outbreak[['alpha3', 'Country', 'Total', year_pop]]
print(str(len(df_outbreak_raw) - df_outbreak.alpha3.notnull().sum()) + " row(s) have NaN as ISO 3 (alpha3).")
df_outbreak.sort_values(by='alpha3').head(5)
# Out:
# 194
# 0 row(s) have NaN as ISO 3 (alpha3).
#     alpha3               Country   Total    pop2019
# 78     AFG           Afghanistan   166.0  38041.754
# 16     AGO                Angola  2962.0  31825.295
# 62     ALB               Albania   481.0   2880.917
# 170    AND               Andorra     0.0     77.142
# 79     ARE  United Arab Emirates   164.0   9770.529

# %% [markdown]
# #### Import $V_{ij}^{t}$

# %%
# IATA data
in_table = r'C:\Users\Ensheng\Desktop\mapping\IATA\flow_XY.csv'
df_iata = pd.read_csv(in_table)
df_iata = df_iata.loc[df_iata['year'] == year_iata] # slice for certain year
df_iata = df_iata[['FIPS', 'ISO', 'paxVolume']]
print(len(df_iata))
df_iata.head(5)
# Out:
# 38265
#            FIPS  ISO  paxVolume
# 370971  46013.0  ARE         17
# 370972  48441.0  ARE         16
# 370973  17167.0  ARE          8
# 370974   5119.0  ARE        496
# 370975  39153.0  ARE         81

# %% [markdown]
# #### Import $UVR_{j}^{t}$ and $P_{j}^{t}$

# %%
in_table = r'C:\Users\Ensheng\Desktop\mapping\Data_NME\Data_VR_AllCounties.csv'
df_nme = pd.read_csv(in_table)
print(len(df_nme))
df_nme.head(5)
# Out:
# 3085
#    FIPS       County      VR     UVR  Population
# 0  1001  Autauga, AL  0.9639  0.0361       55504
# 1  1003  Baldwin, AL  0.9653  0.0347      212628
# 2  1005  Barbour, AL  0.8827  0.1173       25270
# 3  1007     Bibb, AL  0.9454  0.0546       22668
# 4  1009   Blount, AL  0.9730  0.0270       58013

# %%
# in_table = r'C:\Users\Ensheng\Desktop\mapping\diffusion_model\ModelInputOutputAll 4_23.csv'
# df_fipspop = pd.read_csv(in_table)
# df_fipspop = df_fipspop[['FIPS','Population']]
# print(len(df_fipspop))
# df_fipspop.head(5)

# %%
# # merge county population
# df_temp = pd.merge(df_nme, df_fipspop, how='left', left_on='FIPS',right_on='FIPS')
# df_temp.head(5)
# df_nme = df_temp
# print(len(df_nme))
# df_nme.head(5)

# %% [markdown]
# #### Calculate $r_{ij}^{t}$

# %%
df_temp = pd.merge(df_iata, df_outbreak, how='left', left_on='ISO',right_on='alpha3')
df_factors = pd.merge(df_temp, df_nme, how='left', left_on='FIPS',right_on='FIPS')
df_factors.head(5)
# Out:
#       FIPS  ISO  paxVolume alpha3               Country  Total   pop2019  \
# 0  46013.0  ARE         17    ARE  United Arab Emirates  164.0  9770.529
# 1  48441.0  ARE         16    ARE  United Arab Emirates  164.0  9770.529
# 2  17167.0  ARE          8    ARE  United Arab Emirates  164.0  9770.529
# 3   5119.0  ARE        496    ARE  United Arab Emirates  164.0  9770.529
# 4  39153.0  ARE         81    ARE  United Arab Emirates  164.0  9770.529
#
#          County        VR       UVR  Population
# 0     Brown, SD  0.974000  0.026000     39178.0
# 1    Taylor, TX  0.983322  0.016678    136290.0
# 2  Sangamon, IL  0.982722  0.017278    196452.0
# 3   Pulaski, AR  0.942000  0.058000    393956.0
# 4    Summit, OH  0.916000  0.084000    541228.0

# %%
# rename and reorder col.
df_factors.loc[:,('FIPS_Pop')] = df_factors['Population']
df_factors.loc[:,('ISO_Case')] = df_factors['Total']
df_factors.loc[:,('ISO_Pop')] = df_factors[year_pop]
df_factors = df_factors[['FIPS','County','UVR','FIPS_Pop','ISO','Country','ISO_Case','ISO_Pop','paxVolume']]
print(len(df_factors))
df_factors.head(5)
# Out:
# 38265
#       FIPS        County       UVR  FIPS_Pop  ISO               Country  \
# 0  46013.0     Brown, SD  0.026000   39178.0  ARE  United Arab Emirates
# 1  48441.0    Taylor, TX  0.016678  136290.0  ARE  United Arab Emirates
# 2  17167.0  Sangamon, IL  0.017278  196452.0  ARE  United Arab Emirates
# 3   5119.0   Pulaski, AR  0.058000  393956.0  ARE  United Arab Emirates
# 4  39153.0    Summit, OH  0.084000  541228.0  ARE  United Arab Emirates
#
#    ISO_Case   ISO_Pop  paxVolume
# 0     164.0  9770.529         17
# 1     164.0  9770.529         16
# 2     164.0  9770.529          8
# 3     164.0  9770.529        496
# 4     164.0  9770.529         81

# %%
# slice
df_factors = df_factors.loc[df_factors['ISO_Case'].notnull()]
print(len(df_factors))
df_factors = df_factors.loc[df_factors['paxVolume'].notnull()]
print(len(df_factors))
# Out:
# 32905
# 32905

# %% [markdown]
# #### Calculate $r_{j}^{t}$
# ##### (Update FIPS_NME to UVR)

# %%
df_factors['Route_Risk'] = (df_factors['ISO_Case'] / df_factors['ISO_Pop']) * df_factors['paxVolume'] * df_factors['UVR'] * df_factors['FIPS_Pop']

# %%
df_risk = df_factors.groupby(['FIPS','County']).agg({'Route_Risk':'sum', 'paxVolume':'sum','UVR':'mean'}).reset_index()
df_risk.loc[:,('FIPS_RawRisk')] = df_risk['Route_Risk']
df_risk.head(5)
# Out:
#      FIPS         County    Route_Risk  paxVolume     UVR  FIPS_RawRisk
# 0  1033.0    Colbert, AL  3.340325e+02         22  0.1061  3.340325e+02
# 1  1045.0       Dale, AL  2.881982e+05       4754  0.0636  2.881982e+05
# 2  1073.0  Jefferson, AL  8.324975e+07     115308  0.0683  8.324975e+07
# 3  1089.0    Madison, AL  1.989419e+07      54155  0.0417  1.989419e+07
# 4  1097.0     Mobile, AL  4.544242e+07      32531  0.0808  4.544242e+07

# %% [markdown]
# #### Normalize and list the Top 25

# %%
# import county seats
# ref: https://en.wikipedia.org/wiki/List_of_the_most_populous_counties_in_the_United_States
in_table = r'C:\Users\Ensheng\Desktop\mapping\Data_NME\County_CitySeats.xlsx'
df_seat = pd.read_excel(in_table)
print(len(df_seat))
df_seat.head(3)
# Out:
# 64
#     FIPS         City
# 0  35001  Albuquerque
# 1  48453       Austin
# 2   6029  Bakersfield

# %%
highest_risk = df_risk['FIPS_RawRisk'].max()
df_risk['Risk'] = df_risk['FIPS_RawRisk'] / highest_risk
df_risk['FIPS_Rank'] = df_risk['Risk'].rank(ascending=False)
df_risk = pd.merge(df_risk, df_seat, how='left', left_on='FIPS',right_on='FIPS')
df_risk['Year'] = year
df_risk = df_risk[['FIPS','County','City','FIPS_RawRisk','Risk','FIPS_Rank','Year','paxVolume','UVR']]
df_risk = df_risk.sort_values('Risk',ascending = False).reset_index(drop=True)
df_risk = pd.merge(df_risk, real_case, how='left', left_on='FIPS',right_on='FIPS')
df_risk.head(25)
# Out:
#        FIPS            County             City  FIPS_RawRisk      Risk  \
# 0    6037.0   Los Angeles, CA      Los Angeles  2.399430e+11  1.000000
# 1   53033.0          King, WA          Seattle  5.370450e+10  0.223822
# 2   12086.0    Miami-Dade, FL            Miami  2.010316e+10  0.083783
# 3   17031.0          Cook, IL          Chicago  1.672693e+10  0.069712
# 4   15003.0      Honolulu, HI         Honolulu  1.412915e+10  0.058885
# 5   36081.0        Queens, NY      Queens, NYC  1.123462e+10  0.046822
# 6   25025.0       Suffolk, MA           Boston  9.364420e+09  0.039028
# 7   48201.0        Harris, TX          Houston  8.384134e+09  0.034942
# 8    4013.0      Maricopa, AZ          Phoenix  7.963476e+09  0.033189
# 9    6081.0     San Mateo, CA     Redwood City  6.754690e+09  0.028151
# 10   6073.0     San Diego, CA        San Diego  5.634689e+09  0.023483
# 11  12095.0        Orange, FL          Orlando  5.589828e+09  0.023296
# 12  32003.0         Clark, NV        Las Vegas  5.099042e+09  0.021251
# 13  26163.0         Wayne, MI          Detroit  4.860651e+09  0.020258
# 14  34013.0         Essex, NJ           Newark  4.135186e+09  0.017234
# 15  48439.0       Tarrant, TX       Fort Worth  3.611049e+09  0.015050
# 16  49035.0     Salt Lake, UT   Salt Lake City  2.608373e+09  0.010871
# 17  51107.0       Loudoun, VA              NaN  2.071320e+09  0.008633
# 18  18097.0        Marion, IN     Indianapolis  1.995132e+09  0.008315
# 19  12011.0       Broward, FL  Fort Lauderdale  1.818120e+09  0.007577
# 20   8031.0        Denver, CO           Denver  1.334805e+09  0.005563
# 21  42101.0  Philadelphia, PA     Philadelphia  1.200844e+09  0.005005
# 22  39035.0      Cuyahoga, OH        Cleveland  1.180533e+09  0.004920
# 23  41051.0     Multnomah, OR         Portland  1.177668e+09  0.004908
# 24  37119.0   Mecklenburg, NC        Charlotte  1.023065e+09  0.004264
#
#     FIPS_Rank  Year  paxVolume       UVR  # of Cases  intl_case
# 0         1.0  2019   10930679  0.055000        22.0        1.0
# 1         2.0  2019    2195272  0.290000        13.0        1.0
# 2         3.0  2019    7100255  0.051628         NaN        NaN
# 3         4.0  2019    5444790  0.020475         2.0        1.0
# 4         5.0  2019    2713840  0.085000         1.0        NaN
# 5         6.0  2019   15428483  0.010000         7.0        1.0
# 6         7.0  2019    3882798  0.140000         1.0        NaN
# 7         8.0  2019    3178338  0.025232         4.0        1.0
# 8         9.0  2019    1276180  0.073000         NaN        NaN
# 9        10.0  2019    6125305  0.034000         6.0        1.0
# 10       11.0  2019     953817  0.075000         2.0        1.0
# 11       12.0  2019    4024041  0.051600         NaN        NaN
# 12       13.0  2019    2659364  0.049000         1.0        1.0
# 13       14.0  2019    1310061  0.079700         3.0        1.0
# 14       15.0  2019    5529275  0.039000         2.0        1.0
# 15       16.0  2019    2224168  0.044130         1.0        1.0
# 16       17.0  2019     565150  0.089000         NaN        NaN
# 17       18.0  2019    3279006  0.046000         NaN        NaN
# 18       19.0  2019     395382  0.330000         NaN        NaN
# 19       20.0  2019    3076763  0.036524         1.0        1.0
# 20       21.0  2019    1613248  0.060739         1.0        1.0
# 21       22.0  2019    1251378  0.038000         NaN        NaN
# 22       23.0  2019     454271  0.084000         NaN        NaN
# 23       24.0  2019     894747  0.050000        15.0        1.0
# 24       25.0  2019     712023  0.058000         NaN        NaN

# %%
result = df_risk
output_csv = out_folder + 'MeaslesRisk_US_' +  str(year) + '_raw_' + t.strftime('%m%d%y%H%M') + '.csv'
#result.to_csv(output_csv, index=False, encoding='utf-8')

# %%
df_complete = pd.merge(df_factors, df_risk , how='left', left_on='FIPS',right_on='FIPS')
df_complete = df_complete.sort_values(by=['Risk','Route_Risk'], ascending=False)
df_complete['Route_Rank'] = df_complete.groupby('FIPS_Rank')['Route_Risk'].rank(ascending=False,method='dense')
df_complete = df_complete.rename(index=str, columns={"County_x": "County"})
df_complete = df_complete.drop(columns=['County_y'])
df_complete = df_complete.rename(index=str, columns={"paxVolume_x": "paxVolume_route"})
df_complete = df_complete.rename(index=str, columns={"paxVolume_y": "paxVolume_county"})
df_complete = df_complete.rename(index=str, columns={"UVR_y": "UVR"})
df_complete = df_complete.drop(columns=['UVR_x'])
print(len(df_complete))
df_complete.head(5)
# Out:
# 32905
#          FIPS           County    FIPS_Pop  ISO      Country  ISO_Case  \
# 25447  6037.0  Los Angeles, CA  10163507.0  PHL  Philippines   42467.0
# 32267  6037.0  Los Angeles, CA  10163507.0  WSM        Samoa    5580.0
# 24384  6037.0  Los Angeles, CA  10163507.0  NZL  New Zealand    1997.0
# 31196  6037.0  Los Angeles, CA  10163507.0  UKR      Ukraine   56986.0
# 14782  6037.0  Los Angeles, CA  10163507.0  ISR       Israel     998.0
#
#           ISO_Pop  paxVolume_route    Route_Risk         City  FIPS_RawRisk  \
# 25447  108116.615           367297  8.064599e+10  Los Angeles  2.399430e+11
# 32267     197.097             2219  3.511703e+10  Los Angeles  2.399430e+11
# 24384    4783.063           114512  2.672571e+10  Los Angeles  2.399430e+11
# 31196   43993.638            19077  1.381321e+10  Los Angeles  2.399430e+11
# 14782    8519.377           137271  8.988926e+09  Los Angeles  2.399430e+11
#
#        Risk  FIPS_Rank    Year  paxVolume_county    UVR  # of Cases  \
# 25447   1.0        1.0  2019.0        10930679.0  0.055        22.0
# 32267   1.0        1.0  2019.0        10930679.0  0.055        22.0
# 24384   1.0        1.0  2019.0        10930679.0  0.055        22.0
# 31196   1.0        1.0  2019.0        10930679.0  0.055        22.0
# 14782   1.0        1.0  2019.0        10930679.0  0.055        22.0
#
#        intl_case  Route_Rank
# 25447        1.0         1.0
# 32267        1.0         2.0
# 24384        1.0         3.0
# 31196        1.0         4.0
# 14782        1.0         5.0

# %%
result = df_complete
output_csv = out_folder + 'MeaslesRisk_US_' +  str(year) + '_raw_route_' + t.strftime('%m%d%y%H%M') + '.csv'
#result.to_csv(output_csv, index=False, encoding='utf-8')

# %% [markdown]
# ## Task 2: Travel volume proportional to the population (or pop density)

# %% [markdown]
# #### Import neighboring relationship table

# %%
in_table = r'C:\Users\Ensheng\Desktop\mapping\diffusion_model\nbr.csv'
df_nbr = pd.read_csv(in_table)
df_nbr = df_nbr[['src_FIPS', 'nbr_FIPS']]
print(len(df_nbr))
df_nbr.head(5)
# Out:
# 18680
#    src_FIPS  nbr_FIPS
# 0    1001.0    1021.0
# 1    1001.0    1047.0
# 2    1001.0    1051.0
# 3    1001.0    1085.0
# 4    1001.0    1101.0

# %%
# find all counties with IATA data
df_iataCounty = df_iata.groupby(['FIPS'])['paxVolume'].sum().reset_index()
df_iataCounty = df_iataCounty.loc[df_iataCounty['paxVolume'].notnull()]
print(str(len(df_nme)) + " counties in the US.")
print(str(len(df_iataCounty)) + " counties have IATA travel data.")
# Out:
# 3085 counties in the US.
# 401 counties have IATA travel data.

# %%
# subset of df_nbr to show only src_FIPS with IATA data
df_temp = pd.merge(df_nbr, df_iataCounty, how='left', left_on='src_FIPS',right_on='FIPS')
df_hub = df_temp.loc[df_temp['paxVolume'].notnull()]
print(str(len(df_hub)) + " neighboring relationships remain.") # we will only work with these counties and their neighbors
print(str(df_hub.src_FIPS.nunique()) + " hub counties.")
df_hub.head(10)
# Out:
# 2260 neighboring relationships remain.
# 396 hub counties.
#      src_FIPS  nbr_FIPS    FIPS  paxVolume
# 97     1033.0    1059.0  1033.0       22.0
# 98     1033.0    1077.0  1033.0       22.0
# 99     1033.0    1079.0  1033.0       22.0
# 100    1033.0   28141.0  1033.0       22.0
# 131    1045.0    1005.0  1045.0     5020.0
# 132    1045.0    1031.0  1045.0     5020.0
# 133    1045.0    1061.0  1045.0     5020.0
# 134    1045.0    1067.0  1045.0     5020.0
# 135    1045.0    1069.0  1045.0     5020.0
# 136    1045.0    1109.0  1045.0     5020.0

# %%
print("The following (island) counties have IATA data but no neighboring counties: ")
print(set(df_iataCounty.FIPS.unique()) - set(df_hub.src_FIPS.unique()))
# Out:
# The following (island) counties have IATA data but no neighboring counties:
# {15007.0, 15001.0, 25019.0, 15003.0, 53055.0}

# %% [markdown]
# #### Update hub county list

# %%
# src_FIPS is the hub county, nbr_FIPS lists all neighboring counties along with itself, the hub county
# this will also clear out the island county issue
df_iataCounty["src_FIPS"] = df_iataCounty["FIPS"]
df_iataCounty["nbr_FIPS"] = df_iataCounty["FIPS"]
df_iataCounty = df_iataCounty[["src_FIPS","nbr_FIPS"]]
df_hub = df_hub[["src_FIPS","nbr_FIPS"]]
df_hub = df_hub.append(df_iataCounty)
print(str(len(df_hub)) + " neighboring relationships remain.")
print(str(df_hub.src_FIPS.nunique()) + " hub counties.")
df_hub = df_hub.sort_values(["src_FIPS","nbr_FIPS"]).reset_index()
df_hub.head(10)
# Out:
# 2661 neighboring relationships remain.
# 401 hub counties.
#    index  src_FIPS  nbr_FIPS
# 0      0    1033.0    1033.0
# 1     97    1033.0    1059.0
# 2     98    1033.0    1077.0
# 3     99    1033.0    1079.0
# 4    100    1033.0   28141.0
# 5    131    1045.0    1005.0
# 6    132    1045.0    1031.0
# 7      1    1045.0    1045.0
# 8    133    1045.0    1061.0
# 9    134    1045.0    1067.0

# %% [markdown]
# #### Merge county population

# %%
df_pop = pd.merge(df_hub, df_nme , how='left', left_on='nbr_FIPS',right_on='FIPS')
df_pop.head(5)
# Out:
#    index  src_FIPS  nbr_FIPS     FIPS          County      VR     UVR  \
# 0      0    1033.0    1033.0   1033.0     Colbert, AL  0.8939  0.1061
# 1     97    1033.0    1059.0   1059.0    Franklin, AL  0.9775  0.0225
# 2     98    1033.0    1077.0   1077.0  Lauderdale, AL  0.9354  0.0646
# 3     99    1033.0    1079.0   1079.0    Lawrence, AL  0.9680  0.0320
# 4    100    1033.0   28141.0  28141.0  Tishomingo, MS  0.9920  0.0080
#
#    Population
# 0     54500.0
# 1     31495.0
# 2     92538.0
# 3     33049.0
# 4     19542.0

# %% [markdown]
# #### Calculate population percentage

# %%
df_pop_tmp = df_pop.groupby(['src_FIPS', 'nbr_FIPS']).agg({'Population': 'sum'})
# Change: groupby df_nbr_tmp and divide by sum
df_poppct = df_pop_tmp.groupby(level=0) \
.apply(lambda x: 100 * x / float(x.sum())) \
.rename(columns={'Population':'POPPCT'}) \
.reset_index()

# %%
print(len(df_poppct)) # should be the same as len(df_hub), the count of neighboring pairs + the count of hub counties
df_poppct.head(15)
# Out:
# 2661
#     src_FIPS  nbr_FIPS     POPPCT
# 0     1033.0    1033.0  23.580416
# 1     1033.0    1059.0  13.626884
# 2     1033.0    1077.0  40.038248
# 3     1033.0    1079.0  14.299251
# 4     1033.0   28141.0   8.455202
# 5     1045.0    1005.0   8.216523
# 6     1045.0    1031.0  16.866796
# 7     1045.0    1045.0  16.005801
# 8     1045.0    1061.0   8.590770
# 9     1045.0    1067.0   5.575335
# 10    1045.0    1069.0  33.928031
# 11    1045.0    1109.0  10.816743
# 12    1073.0    1007.0   1.725704
# 13    1073.0    1009.0   4.416502
# 14    1073.0    1073.0  50.184348

# %% [markdown]
# #### Calculate travel volume for each route

# %%
df_iata.head(5)
# Out:
#            FIPS  ISO  paxVolume
# 370971  46013.0  ARE         17
# 370972  48441.0  ARE         16
# 370973  17167.0  ARE          8
# 370974   5119.0  ARE        496
# 370975  39153.0  ARE         81

# %%
df_route = pd.merge(df_iata, df_poppct, how='left', left_on='FIPS',right_on='src_FIPS')
print(len(df_route))
df_route.head(15)
# Out:
# 258283
#        FIPS  ISO  paxVolume  src_FIPS  nbr_FIPS     POPPCT
# 0   46013.0  ARE         17   46013.0   38021.0   6.631108
# 1   46013.0  ARE         17   46013.0   38081.0   5.262871
# 2   46013.0  ARE         17   46013.0   46013.0  53.444466
# 3   46013.0  ARE         17   46013.0   46037.0   7.531444
# 4   46013.0  ARE         17   46013.0   46045.0   5.346084
# 5   46013.0  ARE         17   46013.0   46049.0   3.177093
# 6   46013.0  ARE         17   46013.0   46089.0   3.309415
# 7   46013.0  ARE         17   46013.0   46091.0   6.553352
# 8   46013.0  ARE         17   46013.0   46115.0   8.744168
# 9   48441.0  ARE         16   48441.0   48059.0   6.718859
# 10  48441.0  ARE         16   48441.0   48083.0   4.061378
# 11  48441.0  ARE         16   48441.0   48151.0   1.869294
# 12  48441.0  ARE         16   48441.0   48253.0   9.627346
# 13  48441.0  ARE         16   48441.0   48353.0   7.115843
# 14  48441.0  ARE         16   48441.0   48399.0   4.945921

# %%
df_route["IncomingTravel"] = df_route["paxVolume"] * df_route["POPPCT"] / 100
df_route.head(15)
# Out:
#        FIPS  ISO  paxVolume  src_FIPS  nbr_FIPS     POPPCT  IncomingTravel
# 0   46013.0  ARE         17   46013.0   38021.0   6.631108        1.127288
# 1   46013.0  ARE         17   46013.0   38081.0   5.262871        0.894688
# 2   46013.0  ARE         17   46013.0   46013.0  53.444466        9.085559
# 3   46013.0  ARE         17   46013.0   46037.0   7.531444        1.280345
# 4   46013.0  ARE         17   46013.0   46045.0   5.346084        0.908834
# 5   46013.0  ARE         17   46013.0   46049.0   3.177093        0.540106
# 6   46013.0  ARE         17   46013.0   46089.0   3.309415        0.562601
# 7   46013.0  ARE         17   46013.0   46091.0   6.553352        1.114070
# 8   46013.0  ARE         17   46013.0   46115.0   8.744168        1.486509
# 9   48441.0  ARE         16   48441.0   48059.0   6.718859        1.075017
# 10  48441.0  ARE         16   48441.0   48083.0   4.061378        0.649821
# 11  48441.0  ARE         16   48441.0   48151.0   1.869294        0.299087
# 12  48441.0  ARE         16   48441.0   48253.0   9.627346        1.540375
# 13  48441.0  ARE         16   48441.0   48353.0   7.115843        1.138535
# 14  48441.0  ARE         16   48441.0   48399.0   4.945921        0.791347

# %%
df_iata_new = df_route.groupby(['nbr_FIPS','ISO'])['IncomingTravel'].sum().reset_index()
print(len(df_iata_new))
df_iata_new.head(5)
# Out:
# 211613
#    nbr_FIPS  ISO  IncomingTravel
# 0    1001.0  ABW       13.182564
# 1    1001.0  AFG        0.790954
# 2    1001.0  AGO        0.922779
# 3    1001.0  ARE       18.455590
# 4    1001.0  ARG        5.536677

# %%
# update df_iata with travel volume for more counties
df_iata_new["FIPS"] = df_iata_new["nbr_FIPS"]
df_iata_new["paxVolume"] = df_iata_new["IncomingTravel"]
df_iata = df_iata_new[["FIPS","ISO","paxVolume"]]
df_iata.head(5)
# Out:
#      FIPS  ISO  paxVolume
# 0  1001.0  ABW  13.182564
# 1  1001.0  AFG   0.790954
# 2  1001.0  AGO   0.922779
# 3  1001.0  ARE  18.455590
# 4  1001.0  ARG   5.536677

# %% [markdown]
# #### Calculate risk (same as Task 1)

# %% [markdown]
# #### Calculate $r_{ij}^{t}$

# %%
df_temp = pd.merge(df_iata, df_outbreak, how='left', left_on='ISO',right_on='alpha3')
df_factors = pd.merge(df_temp, df_nme, how='left', left_on='FIPS',right_on='FIPS')
df_factors.head(5)
# Out:
#      FIPS  ISO  paxVolume alpha3               Country   Total    pop2019  \
# 0  1001.0  ABW  13.182564    NaN                   NaN     NaN        NaN
# 1  1001.0  AFG   0.790954    AFG           Afghanistan   166.0  38041.754
# 2  1001.0  AGO   0.922779    AGO                Angola  2962.0  31825.295
# 3  1001.0  ARE  18.455590    ARE  United Arab Emirates   164.0   9770.529
# 4  1001.0  ARG   5.536677    ARG             Argentina    64.0  44780.677
#
#         County      VR     UVR  Population
# 0  Autauga, AL  0.9639  0.0361     55504.0
# 1  Autauga, AL  0.9639  0.0361     55504.0
# 2  Autauga, AL  0.9639  0.0361     55504.0
# 3  Autauga, AL  0.9639  0.0361     55504.0
# 4  Autauga, AL  0.9639  0.0361     55504.0

# %%
# rename and reorder col.
df_factors.loc[:,('FIPS_Pop')] = df_factors['Population']
df_factors.loc[:,('ISO_Case')] = df_factors['Total']
df_factors.loc[:,('ISO_Pop')] = df_factors[year_pop]
df_factors = df_factors[['FIPS','County','UVR','FIPS_Pop','ISO','Country','ISO_Case','ISO_Pop','paxVolume']]
print(len(df_factors))
df_factors.head(5)
# Out:
# 211613
#      FIPS       County     UVR  FIPS_Pop  ISO               Country  ISO_Case  \
# 0  1001.0  Autauga, AL  0.0361   55504.0  ABW                   NaN       NaN
# 1  1001.0  Autauga, AL  0.0361   55504.0  AFG           Afghanistan     166.0
# 2  1001.0  Autauga, AL  0.0361   55504.0  AGO                Angola    2962.0
# 3  1001.0  Autauga, AL  0.0361   55504.0  ARE  United Arab Emirates     164.0
# 4  1001.0  Autauga, AL  0.0361   55504.0  ARG             Argentina      64.0
#
#      ISO_Pop  paxVolume
# 0        NaN  13.182564
# 1  38041.754   0.790954
# 2  31825.295   0.922779
# 3   9770.529  18.455590
# 4  44780.677   5.536677

# %%
# slice
df_factors = df_factors.loc[df_factors['ISO_Case'].notnull()]
print(len(df_factors))
df_factors = df_factors.loc[df_factors['paxVolume'].notnull()]
print(len(df_factors))
# Out:
# 181923
# 181923

# %% [markdown]
# #### Calculate $r_{j}^{t}$

# %%
df_factors['Route_Risk'] = (df_factors['ISO_Case'] / df_factors['ISO_Pop']) * df_factors['paxVolume'] * df_factors['UVR'] * df_factors['FIPS_Pop']

# %%
#df_risk = df_factors.groupby(['FIPS','County'])['Route_Risk'].sum().reset_index()
df_risk = df_factors.groupby(['FIPS','County']).agg({'Route_Risk':'sum', 'paxVolume':'sum','UVR':'mean'}).reset_index()
df_risk.loc[:,('FIPS_RawRisk')] = df_risk['Route_Risk']
df_risk.head(5)
# Out:
#      FIPS       County    Route_Risk     paxVolume     UVR  FIPS_RawRisk
# 0  1001.0  Autauga, AL  6.029552e+04   1587.576203  0.0361  6.029552e+04
# 1  1003.0  Baldwin, AL  6.402396e+06  27993.318657  0.0347  6.402396e+06
# 2  1005.0  Barbour, AL  2.241976e+04    390.613524  0.1173  2.241976e+04
# 3  1007.0     Bibb, AL  3.949291e+04   1989.874580  0.0546  3.949291e+04
# 4  1009.0   Blount, AL  1.279129e+05   5092.579583  0.0270  1.279129e+05

# %% [markdown]
# #### Normalize and list the Top 25

# %%
highest_risk = df_risk['FIPS_RawRisk'].max()
df_risk['Risk'] = df_risk['FIPS_RawRisk'] / highest_risk
df_risk['FIPS_Rank'] = df_risk['Risk'].rank(ascending=False)
df_risk = pd.merge(df_risk, df_seat, how='left', left_on='FIPS',right_on='FIPS')
df_risk['Year'] = year
df_risk = df_risk[['FIPS','County','City','FIPS_RawRisk','Risk','FIPS_Rank','Year','paxVolume','UVR']]
df_risk = df_risk.sort_values('Risk',ascending = False).reset_index(drop=True)
df_risk = pd.merge(df_risk, real_case, how='left', left_on='FIPS',right_on='FIPS')
df_risk.head(25)
# Out:
#        FIPS              County             City  FIPS_RawRisk      Risk  \
# 0    6037.0     Los Angeles, CA      Los Angeles  1.422186e+11  1.000000
# 1   53033.0            King, WA          Seattle  2.611759e+10  0.183644
# 2   15003.0        Honolulu, HI         Honolulu  1.412915e+10  0.099348
# 3   12086.0      Miami-Dade, FL            Miami  1.231123e+10  0.086566
# 4    6059.0          Orange, CA        Santa Ana  1.208046e+10  0.084943
# 5   17031.0            Cook, IL          Chicago  9.830657e+09  0.069124
# 6    6071.0  San Bernardino, CA   San Bernardino  8.056249e+09  0.056647
# 7    4013.0        Maricopa, AZ          Phoenix  6.086527e+09  0.042797
# 8   48201.0          Harris, TX          Houston  5.684577e+09  0.039971
# 9   51059.0  Fairfax County, VA              NaN  5.651831e+09  0.039740
# 10  53053.0          Pierce, WA              NaN  5.477565e+09  0.038515
# 11   6085.0     Santa Clara, CA         San Jose  4.960643e+09  0.034880
# 12   6001.0         Alameda, CA          Oakland  4.600054e+09  0.032345
# 13  12011.0         Broward, FL  Fort Lauderdale  4.407438e+09  0.030991
# 14  53061.0       Snohomish, WA              NaN  3.692158e+09  0.025961
# 15  36047.0           Kings, NY              NaN  3.513096e+09  0.024702
# 16  36081.0          Queens, NY      Queens, NYC  2.785500e+09  0.019586
# 17  32003.0           Clark, NV        Las Vegas  2.445992e+09  0.017199
# 18  25025.0         Suffolk, MA           Boston  2.409460e+09  0.016942
# 19   6073.0       San Diego, CA        San Diego  2.204233e+09  0.015499
# 20  26163.0           Wayne, MI          Detroit  1.940272e+09  0.013643
# 21  25017.0       Middlesex, MA              NaN  1.879626e+09  0.013216
# 22  12095.0          Orange, FL          Orlando  1.788989e+09  0.012579
# 23   6029.0            Kern, CA      Bakersfield  1.786059e+09  0.012559
# 24  18089.0            Lake, IN              NaN  1.751251e+09  0.012314
#
#     FIPS_Rank  Year     paxVolume       UVR  # of Cases  intl_case
# 0         1.0  2019  6.601098e+06  0.055000        22.0        1.0
# 1         2.0  2019  1.068388e+06  0.290000        13.0        1.0
# 2         3.0  2019  2.713840e+06  0.085000         1.0        NaN
# 3         4.0  2019  5.100034e+06  0.051628         NaN        NaN
# 4         5.0  2019  2.478160e+06  0.043000         5.0        1.0
# 5         6.0  2019  3.199981e+06  0.020475         2.0        1.0
# 6         7.0  2019  2.688638e+06  0.049000         2.0        1.0
# 7         8.0  2019  9.645015e+05  0.073000         NaN        NaN
# 8         9.0  2019  2.154964e+06  0.025232         4.0        1.0
# 9        10.0  2019  1.327771e+06  0.123000         NaN        NaN
# 10       11.0  2019  4.279920e+05  0.379000         2.0        NaN
# 11       12.0  2019  2.525490e+06  0.027000         6.0        1.0
# 12       13.0  2019  2.167319e+06  0.034000         1.0        NaN
# 13       14.0  2019  3.658756e+06  0.036524         1.0        1.0
# 14       15.0  2019  3.905126e+05  0.306000         1.0        NaN
# 15       16.0  2019  4.295971e+06  0.010000       633.0        1.0
# 16       17.0  2019  3.825321e+06  0.010000         7.0        1.0
# 17       18.0  2019  1.275768e+06  0.049000         1.0        1.0
# 18       19.0  2019  9.990416e+05  0.140000         1.0        NaN
# 19       20.0  2019  4.613189e+05  0.075000         2.0        1.0
# 20       21.0  2019  5.229956e+05  0.079700         3.0        1.0
# 21       22.0  2019  2.017047e+06  0.027000         NaN        NaN
# 22       23.0  2019  1.311159e+06  0.051600         NaN        NaN
# 23       24.0  2019  5.812052e+05  0.089000         NaN        NaN
# 24       25.0  2019  2.982077e+05  0.420000         NaN        NaN

# %%
result = df_risk
output_csv = out_folder + 'MeaslesRisk_US_' +  str(year) + '_pop_' + t.strftime('%m%d%y%H%M') + '.csv'
result.to_csv(output_csv, index=False, encoding='utf-8')

# %%
df_complete = pd.merge(df_factors, df_risk , how='left', left_on='FIPS',right_on='FIPS')
df_complete = df_complete.sort_values(by=['Risk','Route_Risk'], ascending=False)
df_complete['Route_Rank'] = df_complete.groupby('FIPS_Rank')['Route_Risk'].rank(ascending=False,method='dense')
df_complete = df_complete.rename(index=str, columns={"County_x": "County"})
df_complete = df_complete.drop(columns=['County_y'])
df_complete = df_complete.rename(index=str, columns={"paxVolume_x": "paxVolume_route"})
df_complete = df_complete.rename(index=str, columns={"paxVolume_y": "paxVolume_county"})
df_complete = df_complete.rename(index=str, columns={"UVR_y": "UVR"})
df_complete = df_complete.drop(columns=['UVR_x'])
print(len(df_complete))
df_complete.head(5)
# Out:
# 181923
#          FIPS           County    FIPS_Pop  ISO      Country  ISO_Case  \
# 12592  6037.0  Los Angeles, CA  10163507.0  PHL  Philippines   42467.0
# 12632  6037.0  Los Angeles, CA  10163507.0  WSM        Samoa    5580.0
# 12587  6037.0  Los Angeles, CA  10163507.0  NZL  New Zealand    1997.0
# 12627  6037.0  Los Angeles, CA  10163507.0  UKR      Ukraine   56986.0
# 12542  6037.0  Los Angeles, CA  10163507.0  ISR       Israel     998.0
#
#           ISO_Pop  paxVolume_route    Route_Risk         City  FIPS_RawRisk  \
# 12592  108116.615    217667.133001  4.779234e+10  Los Angeles  1.422186e+11
# 12632     197.097      1307.343368  2.068951e+10  Los Angeles  1.422186e+11
# 12587    4783.063     67648.590206  1.578836e+10  Los Angeles  1.422186e+11
# 12627   43993.638     11299.525482  8.181723e+09  Los Angeles  1.422186e+11
# 12542    8519.377     82088.136639  5.375383e+09  Los Angeles  1.422186e+11
#
#        Risk  FIPS_Rank    Year  paxVolume_county    UVR  # of Cases  \
# 12592   1.0        1.0  2019.0      6.601098e+06  0.055        22.0
# 12632   1.0        1.0  2019.0      6.601098e+06  0.055        22.0
# 12587   1.0        1.0  2019.0      6.601098e+06  0.055        22.0
# 12627   1.0        1.0  2019.0      6.601098e+06  0.055        22.0
# 12542   1.0        1.0  2019.0      6.601098e+06  0.055        22.0
#
#        intl_case  Route_Rank
# 12592        1.0         1.0
# 12632        1.0         2.0
# 12587        1.0         3.0
# 12627        1.0         4.0
# 12542        1.0         5.0

# %%
result = df_complete
output_csv = out_folder + 'MeaslesRisk_US_' +  str(year) + '_pop_route_' + t.strftime('%m%d%y%H%M') + '.csv'
result.to_csv(output_csv, index=False, encoding='utf-8')

# %% [markdown]
# ## Task 3: Travel volume proportional to Voronoi diagram

# %%
# environment setting
v_folder = r'C:\Users\Ensheng\Desktop\mapping\Voronoi\\'

# %% [markdown]
# #### Import original $V_{ij}^{t}$

# %%
# IATA data
in_table = r'C:\Users\Ensheng\Desktop\mapping\IATA\flow_XY.csv'
# Note: CSL and SBP are the same airport. CSL -> SBP (Airport count 676 -> 675)
df_iata = pd.read_csv(in_table)
df_iata = df_iata.loc[df_iata['year'] == year_iata] # slice for certain year
# note: FIPS means the state where the airport (IATA) is located. One airport (IATA) has only one associated state (FIPS).
df_iata = df_iata[['ISO', 'Code', 'FIPS', 'paxVolume']]
print(len(df_iata))
df_iata.head(5)
# Out:
# 38265
#         ISO Code     FIPS  paxVolume
# 370971  ARE  ABR  46013.0         17
# 370972  ARE  ABI  48441.0         16
# 370973  ARE  SPI  17167.0          8
# 370974  ARE  LIT   5119.0        496
# 370975  ARE  CAK  39153.0         81

# %%
print("Warning: " + str(len(df_iata.loc[df_iata['Code'].isnull()])) + " airport(s) missing info.")
# Out:
# Warning: 0 airport(s) missing info.

# %% [markdown]
# #### Update incoming travel volume data

# %%
# Thiessen data
in_table = v_folder + 'Thiessen_County_Intersect_Pct.csv'
df_tpct = pd.read_csv(in_table)
# note: FIPS_1 means all states within an airport Thiessen polygon. One airport (Code) has at least one associated state (FIPS_1).
# The sum of ThiessenAreaPct for the same airport should be 100%.
df_tpct = df_tpct[['Code', 'FIPS_1', 'ThiessenAreaPct']]
print(len(df_tpct))
df_tpct.sort_values(by='Code').head(15)
# Out:
# 7137
#      Code  FIPS_1  ThiessenAreaPct
# 6071  ABE   42095        14.276210
# 6070  ABE   42089        11.460134
# 6069  ABE   42011        14.898813
# 6068  ABE   42077        13.235343
# 6067  ABE   42017         8.398984
# 6066  ABE   42091         5.618685
# 6065  ABE   42103         0.115441
# 6064  ABE   34041         8.097077
# 6063  ABE   42107        10.020279
# 6061  ABE   42025        10.374824
# 6062  ABE   34019         3.324779
# 6072  ABE   42029         0.179431
# 530   ABI   48263         1.805562
# 543   ABI   48415         4.780964
# 531   ABI   48133         1.247477

# %%
# diffuse the travel volume to each county (make sure there is no null values after the left join)
df_temp = pd.merge(df_iata, df_tpct, how='left', on='Code')
df_temp.loc[df_temp['FIPS_1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ISO, Code, FIPS, paxVolume, FIPS_1, ThiessenAreaPct]
# Index: []

# %%
df_temp['travelVolume'] = df_temp['paxVolume'] * df_temp['ThiessenAreaPct'] / 100
print(len(df_temp))
df_temp.sort_values(by=['ISO','Code']).head(15)
# Out:
# 483595
#        ISO Code     FIPS  paxVolume  FIPS_1  ThiessenAreaPct  travelVolume
# 29360  ABW  ABE  42077.0        534   42025        10.374824     55.401560
# 29361  ABW  ABE  42077.0        534   34019         3.324779     17.754319
# 29362  ABW  ABE  42077.0        534   42107        10.020279     53.508292
# 29363  ABW  ABE  42077.0        534   34041         8.097077     43.238391
# 29364  ABW  ABE  42077.0        534   42103         0.115441      0.616457
# 29365  ABW  ABE  42077.0        534   42091         5.618685     30.003779
# 29366  ABW  ABE  42077.0        534   42017         8.398984     44.850574
# 29367  ABW  ABE  42077.0        534   42077        13.235343     70.676731
# 29368  ABW  ABE  42077.0        534   42011        14.898813     79.559661
# 29369  ABW  ABE  42077.0        534   42089        11.460134     61.197117
# 29370  ABW  ABE  42077.0        534   42095        14.276210     76.234961
# 29371  ABW  ABE  42077.0        534   42029         0.179431      0.958159
# 27738  ABW  ABI  48441.0          8   48353         7.389170      0.591134
# 27739  ABW  ABI  48441.0          8   48151         7.841060      0.627285
# 27740  ABW  ABI  48441.0          8   48399         4.512294      0.360984

# %%
df = df_temp.groupby(['ISO','FIPS_1'])['travelVolume'].sum().reset_index()
# update df_iata with travel volume for more counties
df["FIPS"] = df["FIPS_1"]
df["paxVolume"] = df["travelVolume"]
df = df[["FIPS","ISO","paxVolume"]]
df.head(5)
# Out:
#    FIPS  ISO  paxVolume
# 0  1001  ABW   7.354981
# 1  1003  ABW  34.524634
# 2  1005  ABW   0.491665
# 3  1007  ABW  85.469930
# 4  1009  ABW  82.550875

# %%
df_iata = df
print(len(df_iata))
df_iata.head(5)
# Out:
# 360692
#    FIPS  ISO  paxVolume
# 0  1001  ABW   7.354981
# 1  1003  ABW  34.524634
# 2  1005  ABW   0.491665
# 3  1007  ABW  85.469930
# 4  1009  ABW  82.550875

# %% [markdown]
# #### Calculate risk (same as Task 1)

# %% [markdown]
# #### Calculate $r_{ij}^{t}$

# %%
df_temp = pd.merge(df_iata, df_outbreak, how='left', left_on='ISO',right_on='alpha3')
df_factors = pd.merge(df_temp, df_nme, how='left', left_on='FIPS',right_on='FIPS')
df_factors.head(5)
# Out:
#    FIPS  ISO  paxVolume alpha3 Country  Total  pop2019       County      VR  \
# 0  1001  ABW   7.354981    NaN     NaN    NaN      NaN  Autauga, AL  0.9639
# 1  1003  ABW  34.524634    NaN     NaN    NaN      NaN  Baldwin, AL  0.9653
# 2  1005  ABW   0.491665    NaN     NaN    NaN      NaN  Barbour, AL  0.8827
# 3  1007  ABW  85.469930    NaN     NaN    NaN      NaN     Bibb, AL  0.9454
# 4  1009  ABW  82.550875    NaN     NaN    NaN      NaN   Blount, AL  0.9730
#
#       UVR  Population
# 0  0.0361     55504.0
# 1  0.0347    212628.0
# 2  0.1173     25270.0
# 3  0.0546     22668.0
# 4  0.0270     58013.0

# %%
# rename and reorder col.
df_factors.loc[:,('FIPS_Pop')] = df_factors['Population']
df_factors.loc[:,('ISO_Case')] = df_factors['Total']
df_factors.loc[:,('ISO_Pop')] = df_factors[year_pop]
df_factors = df_factors[['FIPS','County','UVR','FIPS_Pop','ISO','Country','ISO_Case','ISO_Pop','paxVolume']]
print(len(df_factors))
df_factors.head(5)
# Out:
# 360692
#    FIPS       County     UVR  FIPS_Pop  ISO Country  ISO_Case  ISO_Pop  \
# 0  1001  Autauga, AL  0.0361   55504.0  ABW     NaN       NaN      NaN
# 1  1003  Baldwin, AL  0.0347  212628.0  ABW     NaN       NaN      NaN
# 2  1005  Barbour, AL  0.1173   25270.0  ABW     NaN       NaN      NaN
# 3  1007     Bibb, AL  0.0546   22668.0  ABW     NaN       NaN      NaN
# 4  1009   Blount, AL  0.0270   58013.0  ABW     NaN       NaN      NaN
#
#    paxVolume
# 0   7.354981
# 1  34.524634
# 2   0.491665
# 3  85.469930
# 4  82.550875

# %%
# slice
df_factors = df_factors.loc[df_factors['ISO_Case'].notnull()]
print(len(df_factors))
df_factors = df_factors.loc[df_factors['paxVolume'].notnull()]
print(len(df_factors))
# Out:
# 309581
# 309581

# %% [markdown]
# #### Calculate $r_{j}^{t}$

# %%
df_factors['Route_Risk'] = (df_factors['ISO_Case'] / df_factors['ISO_Pop']) * df_factors['paxVolume'] * df_factors['UVR'] * df_factors['FIPS_Pop']

# %%
#df_risk = df_factors.groupby(['FIPS','County'])['Route_Risk'].sum().reset_index()
df_risk = df_factors.groupby(['FIPS','County']).agg({'Route_Risk':'sum', 'paxVolume':'sum','UVR':'mean'}).reset_index()
df_risk.loc[:,('FIPS_RawRisk')] = df_risk['Route_Risk']
df_risk.head(5)
# Out:
#    FIPS       County    Route_Risk     paxVolume     UVR  FIPS_RawRisk
# 0  1001  Autauga, AL  3.364083e+04    885.760340  0.0361  3.364083e+04
# 1  1003  Baldwin, AL  1.571583e+06   5521.720125  0.0347  1.571583e+06
# 2  1005  Barbour, AL  4.669838e+04    737.650168  0.1173  4.669838e+04
# 3  1007     Bibb, AL  2.180953e+05  10985.952798  0.0546  2.180953e+05
# 4  1009   Blount, AL  3.043443e+05  11312.195605  0.0270  3.043443e+05

# %% [markdown]
# #### Normalize and list the Top 25

# %%
highest_risk = df_risk['FIPS_RawRisk'].max()
df_risk['Risk'] = df_risk['FIPS_RawRisk'] / highest_risk
df_risk['FIPS_Rank'] = df_risk['Risk'].rank(ascending=False)
df_risk = pd.merge(df_risk, df_seat, how='left', left_on='FIPS',right_on='FIPS')
df_risk['Year'] = year
df_risk = df_risk[['FIPS','County','City','FIPS_RawRisk','Risk','FIPS_Rank','Year','paxVolume','UVR']]
df_risk = df_risk.sort_values('Risk',ascending = False).reset_index(drop=True)
df_risk = pd.merge(df_risk, real_case, how='left', left_on='FIPS',right_on='FIPS')
df_risk.head(25)
# Out:
#      FIPS              County             City  FIPS_RawRisk      Risk  \
# 0    6037     Los Angeles, CA      Los Angeles  2.399306e+11  1.000000
# 1   15003        Honolulu, HI         Honolulu  1.412840e+10  0.058885
# 2   12086      Miami-Dade, FL            Miami  1.310357e+10  0.054614
# 3   53033            King, WA          Seattle  9.903356e+09  0.041276
# 4   53053          Pierce, WA              NaN  8.880764e+09  0.037014
# 5    4013        Maricopa, AZ          Phoenix  7.515875e+09  0.031325
# 6    6081       San Mateo, CA     Redwood City  6.755072e+09  0.028154
# 7    6073       San Diego, CA        San Diego  5.645237e+09  0.023529
# 8   34025        Monmouth, NJ              NaN  5.512127e+09  0.022974
# 9   32003           Clark, NV        Las Vegas  3.327249e+09  0.013868
# 10  17031            Cook, IL          Chicago  3.039828e+09  0.012670
# 11  36081          Queens, NY      Queens, NYC  2.955306e+09  0.012317
# 12  12011         Broward, FL  Fort Lauderdale  2.400938e+09  0.010007
# 13  36047           Kings, NY              NaN  1.951270e+09  0.008133
# 14  26163           Wayne, MI          Detroit  1.815025e+09  0.007565
# 15  48201          Harris, TX          Houston  1.396073e+09  0.005819
# 16  51059  Fairfax County, VA              NaN  1.325338e+09  0.005524
# 17  53067        Thurston, WA              NaN  1.163793e+09  0.004851
# 18  36059          Nassau, NY              NaN  1.056438e+09  0.004403
# 19  12095          Orange, FL          Orlando  1.038291e+09  0.004327
# 20  34023       Middlesex, NJ              NaN  8.617977e+08  0.003592
# 21  25025         Suffolk, MA           Boston  7.472403e+08  0.003114
# 22  25009           Essex, MA              NaN  7.156005e+08  0.002983
# 23  12105            Polk, FL              NaN  6.832135e+08  0.002848
# 24  25023        Plymouth, MA              NaN  5.282070e+08  0.002201
#
#     FIPS_Rank  Year     paxVolume       UVR  # of Cases  intl_case
# 0         1.0  2019  1.092944e+07  0.055000        22.0        1.0
# 1         2.0  2019  2.713697e+06  0.085000         1.0        NaN
# 2         3.0  2019  4.676139e+06  0.051628         NaN        NaN
# 3         4.0  2019  4.045218e+05  0.290000        13.0        1.0
# 4         5.0  2019  6.903668e+05  0.379000         2.0        NaN
# 5         6.0  2019  1.196394e+06  0.073000         NaN        NaN
# 6         7.0  2019  6.126696e+06  0.034000         6.0        1.0
# 7         8.0  2019  9.606734e+05  0.075000         2.0        1.0
# 8         9.0  2019  7.086960e+06  0.040000         2.0        NaN
# 9        10.0  2019  1.735306e+06  0.049000         1.0        1.0
# 10       11.0  2019  9.912932e+05  0.020475         2.0        1.0
# 11       12.0  2019  4.154647e+06  0.010000         7.0        1.0
# 12       13.0  2019  3.019494e+06  0.036524         1.0        1.0
# 13       14.0  2019  2.219480e+06  0.010000       633.0        1.0
# 14       15.0  2019  4.891925e+05  0.079700         3.0        1.0
# 15       16.0  2019  5.240906e+05  0.025232         4.0        1.0
# 16       17.0  2019  3.488132e+05  0.123000         NaN        NaN
# 17       18.0  2019  2.943407e+05  0.364000         NaN        NaN
# 18       19.0  2019  2.434271e+06  0.010000         2.0        1.0
# 19       20.0  2019  7.494904e+05  0.051600         NaN        NaN
# 20       21.0  2019  1.657735e+06  0.026000         NaN        NaN
# 21       22.0  2019  3.098305e+05  0.140000         1.0        NaN
# 22       23.0  2019  1.141084e+06  0.037000         NaN        NaN
# 23       24.0  2019  1.740629e+06  0.028653         NaN        NaN
# 24       25.0  2019  9.894682e+05  0.048000         1.0        NaN

# %%
result = df_risk
output_csv = out_folder + 'MeaslesRisk_US_' +  str(year) + '_voronoi_' + t.strftime('%m%d%y%H%M') + '.csv'
#result.to_csv(output_csv, index=False, encoding='utf-8')

# %%
df_complete = pd.merge(df_factors, df_risk , how='left', left_on='FIPS',right_on='FIPS')
df_complete = df_complete.sort_values(by=['Risk','Route_Risk'], ascending=False)
df_complete['Route_Rank'] = df_complete.groupby('FIPS_Rank')['Route_Risk'].rank(ascending=False,method='dense')
df_complete = df_complete.rename(index=str, columns={"County_x": "County"})
df_complete = df_complete.drop(columns=['County_y'])
df_complete = df_complete.rename(index=str, columns={"paxVolume_x": "paxVolume_route"})
df_complete = df_complete.rename(index=str, columns={"paxVolume_y": "paxVolume_county"})
df_complete = df_complete.rename(index=str, columns={"UVR_y": "UVR"})
df_complete = df_complete.drop(columns=['UVR_x'])
print(len(df_complete))
df_complete.head(5)
# Out:
# 309581
#         FIPS           County    FIPS_Pop  ISO      Country  ISO_Case  \
# 238812  6037  Los Angeles, CA  10163507.0  PHL  Philippines   42467.0
# 303140  6037  Los Angeles, CA  10163507.0  WSM        Samoa    5580.0
# 227613  6037  Los Angeles, CA  10163507.0  NZL  New Zealand    1997.0
# 294013  6037  Los Angeles, CA  10163507.0  UKR      Ukraine   56986.0
# 145317  6037  Los Angeles, CA  10163507.0  ISR       Israel     998.0
#
#            ISO_Pop  paxVolume_route    Route_Risk         City  FIPS_RawRisk  \
# 238812  108116.615    367335.431398  8.065443e+10  Los Angeles  2.399306e+11
# 303140     197.097      2219.867414  3.513076e+10  Los Angeles  2.399306e+11
# 227613    4783.063    114705.664906  2.677091e+10  Los Angeles  2.399306e+11
# 294013   43993.638     19098.806728  1.382900e+10  Los Angeles  2.399306e+11
# 145317    8519.377    137553.806728  9.007445e+09  Los Angeles  2.399306e+11
#
#         Risk  FIPS_Rank    Year  paxVolume_county    UVR  # of Cases  \
# 238812   1.0        1.0  2019.0      1.092944e+07  0.055        22.0
# 303140   1.0        1.0  2019.0      1.092944e+07  0.055        22.0
# 227613   1.0        1.0  2019.0      1.092944e+07  0.055        22.0
# 294013   1.0        1.0  2019.0      1.092944e+07  0.055        22.0
# 145317   1.0        1.0  2019.0      1.092944e+07  0.055        22.0
#
#         intl_case  Route_Rank
# 238812        1.0         1.0
# 303140        1.0         2.0
# 227613        1.0         3.0
# 294013        1.0         4.0
# 145317        1.0         5.0

# %%
result = df_complete
output_csv = out_folder + 'MeaslesRisk_US_' +  str(year) + '_voronoi_route_' + t.strftime('%m%d%y%H%M') + '.csv'
#result.to_csv(output_csv, index=False, encoding='utf-8')
